# %%
#Rotulação 
import numpy as np
import heartpy as hp
import pandas as pd
import os
import glob

# %%
a = pd.read_csv("novapasta\drive0.csv")
a
# Out:
#             bpm         ibi        sdnn                sdsd       rmssd  \
# 0    100.204225  598.777145  158.450721  123.06782636487213  231.500413
# 1     76.500000  784.313725  175.377881                 0.0  196.078431
# 2           NaN         NaN         NaN                  --         NaN
# 3    108.547297  552.754435  164.120056  151.89921691491884  225.076095
# 4    102.822581  583.529412  163.513894   142.4606483171773  248.628931
# ..          ...         ...         ...                 ...         ...
# 123   89.158273  672.960542  179.492858  161.65110942965612  288.417734
# 124  102.744526  583.972720  166.021672  146.20827374956423  265.846149
# 125   93.939210  638.710930  184.379112  156.91681460350216  309.653470
# 126   91.591837  655.080214  181.947020   156.5724195759998  265.305728
# 127  106.163265  565.167243  166.545895  142.33340808790643  207.769782
#
#         pnn20     pnn50      hr_mad         sd1         sd2  ...   sd1/sd2  \
# ...

# %%
path = 'database'
extension = 'csv'
os.chdir(path)
r = glob.glob('*.{}'.format(extension))
print(r)
# Out:
# ['dt1.csv', 'dt10.csv', 'dt11.csv', 'dt12.csv', 'dt13.csv', 'dt14.csv', 'dt15.csv', 'dt16.csv', 'dt17.csv', 'dt2.csv', 'dt3.csv', 'dt4.csv', 'dt5.csv', 'dt6.csv', 'dt7.csv', 'dt8.csv', 'dt9.csv']

# %%
db = pd.read_csv(r[0])
db
# Out:
#             bpm         ibi        sdnn                sdsd       rmssd  \
# 0    100.204225  598.777145  158.450721  123.06782636487213  231.500413
# 1     76.500000  784.313725  175.377881                 0.0  196.078431
# 2           NaN         NaN         NaN                  --         NaN
# 3    108.547297  552.754435  164.120056  151.89921691491884  225.076095
# 4    102.822581  583.529412  163.513894   142.4606483171773  248.628931
# ..          ...         ...         ...                 ...         ...
# 123   89.158273  672.960542  179.492858  161.65110942965612  288.417734
# 124  102.744526  583.972720  166.021672  146.20827374956423  265.846149
# 125   93.939210  638.710930  184.379112  156.91681460350216  309.653470
# 126   91.591837  655.080214  181.947020   156.5724195759998  265.305728
# 127  106.163265  565.167243  166.545895  142.33340808790643  207.769782
#
#         pnn20     pnn50      hr_mad         sd1         sd2              s  \
# ...

# %%
db.describe()
# Out:
#               bpm         ibi        sdnn       rmssd       pnn20       pnn50  \
# count  127.000000  127.000000  127.000000  127.000000  127.000000  127.000000
# mean    97.621338  619.536238  162.058517  239.676157    0.710645    0.710645
# std      8.450921   57.525179   14.090476   26.001265    0.086664    0.086664
# min     76.500000  525.274330  114.332390  172.924922    0.500000    0.500000
# 25%     93.565059  583.264114  156.909925  222.009354    0.651389    0.651389
# 50%     99.280000  604.351330  164.423917  237.047265    0.708333    0.708333
# 75%    102.869360  641.275278  169.059781  255.137599    0.755437    0.755437
# max    114.226027  784.313725  195.613931  325.159293    1.000000    1.000000
#
#            hr_mad         sd1         sd2              s     sd1/sd2  \
# count  127.000000  127.000000  127.000000     127.000000  126.000000
# mean   163.656014  165.028090  149.567663   78307.089696    1.144414
# ...

# %%
x = db['GSR1'].mean()

# %%
#vou adotar o valor de gsr1(gsr do pé), sendo maior que 1,58 para estressado, pois é o valor limite da maior partes dos datasets
db['stress'] = np.where(db['GSR1'] >=x, 1,0)
db.columns
# Out:
# Index(['bpm', 'ibi', 'sdnn', 'sdsd', 'rmssd', 'pnn20', 'pnn50', 'hr_mad',
#        'sd1', 'sd2', 's', 'sd1/sd2', 'breathingrate', 'segment_indices',
#        'time', 'ECG', 'EMG', 'GSR1', 'GSR2', 'HR', 'marker', 'RESP', 'stress'],
#       dtype='object')

# %%
for i in range(0,17):
    b = str(i)
    db = pd.read_csv(r[i])
    x = db['GSR1'].mean()
    db['stress'] = np.where(db['GSR1']>=x,1,0)
    db.to_csv (r'drive'+b+'.csv', index=None)

# %%
path = 'novapasta'
extension = 'csv'
os.chdir(path)
result = glob.glob('*.{}'.format(extension))
print(result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-f28f346a6213> in <module>
#       1 path = 'novapasta'
#       2 extension = 'csv'
# ----> 3 os.chdir(path)
#       4 result = glob.glob('*.{}'.format(extension))
#       5 print(result)
#
# FileNotFoundError: [WinError 2] O sistema não pode encontrar o arquivo especificado: 'novapasta'

# %%
ex = pd.read_csv(result[2])
ex
# Out:
#             bpm         ibi        sdnn        sdsd       rmssd     pnn20  \
# 0     81.728155  734.141126  173.421597  167.180968  283.942755  0.800000
# 1    111.107143  540.019286  109.100371   70.985689   81.967213  0.250000
# 2     94.272727  636.451302  157.866013  131.147541  146.627408  0.200000
# 3    104.571429  573.770492  125.206986  107.467996  130.774432  0.363636
# 4    122.000000  491.803279  156.751293  140.595417  227.758704  0.744186
# ..          ...         ...         ...         ...         ...       ...
# 231   94.114286  637.522769  162.919343  183.284260  306.693228  0.833333
# 232   79.300000  756.620429  176.544767  131.147541  293.254817  1.000000
# 233   79.300000  756.620429  193.312859  172.516198  270.728795  0.727273
# 234   78.428571  765.027322  176.224213   81.967213  115.919144  0.500000
# 235  118.950000  504.413619  150.269550  121.178360  193.604881  0.710526
#
#         pnn50      hr_mad         sd1         sd2              s   sd1/sd2  \
# ...
